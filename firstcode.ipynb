# %%
print("Better Call Saul")
print("----------")
print("   Python   ")
print("----------")
print("Hi \"Python\"")
print("""Your Learning Path:
      \t- Python Basics
      \t- Data Engineering
      \t- AI""")
# Out:
# Better Call Saul
# ----------
#    Python
# ----------
# Hi "Python"
# Your Learning Path:
#       	- Python Basics
#       	- Data Engineering
#       	- AI
